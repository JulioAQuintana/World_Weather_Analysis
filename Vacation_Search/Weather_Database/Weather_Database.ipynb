# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a new set of 2,000 random latitudes and longitudes.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description}
                        )

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | locri
# Processing Record 5 of Set 1 | yulara
# Processing Record 6 of Set 1 | bohicon
# Processing Record 7 of Set 1 | baculin
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | miyako
# Processing Record 10 of Set 1 | cockburn town
# Processing Record 11 of Set 1 | porto nacional
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | rio grande
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | markova
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | visby
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | sola
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | qaqortoq
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | ahipara
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | sapao
# City not found. Skipping...
# Processing Record 33 of Set 1 | aranos
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | miracema do tocantins
# Processing Record 36 of Set 1 | dingle
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | neiafu
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | hun
# Processing Record 44 of Set 1 | tahoua
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | richards bay
# Processing Record 48 of Set 1 | port hedland
# Processing Record 49 of Set 1 | gravdal
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | nemuro
# Processing Record 3 of Set 2 | novyy nekouz
# Processing Record 4 of Set 2 | darnah
# Processing Record 5 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | mount isa
# Processing Record 9 of Set 2 | price
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 2 | broken hill
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | jose de freitas
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | pontianak
# Processing Record 19 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 2 | den helder
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | arua
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | sisimiut
# Processing Record 31 of Set 2 | iquique
# Processing Record 32 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 2 | miraflores
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | tombouctou
# Processing Record 36 of Set 2 | tayoltita
# Processing Record 37 of Set 2 | cootamundra
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | artyom
# Processing Record 44 of Set 2 | shieli
# Processing Record 45 of Set 2 | gamboula
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | safford
# Processing Record 1 of Set 3 | srednekolymsk
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | dali
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | kyabram
# Processing Record 7 of Set 3 | kolokani
# Processing Record 8 of Set 3 | chengde
# Processing Record 9 of Set 3 | alberton
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | tigil
# Processing Record 12 of Set 3 | gao
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | chuy
# Processing Record 15 of Set 3 | vestmanna
# Processing Record 16 of Set 3 | gweta
# Processing Record 17 of Set 3 | safranbolu
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | kenai
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | ballina
# Processing Record 25 of Set 3 | haines junction
# Processing Record 26 of Set 3 | carutapera
# Processing Record 27 of Set 3 | whitehorse
# Processing Record 28 of Set 3 | vigrestad
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | mogadishu
# Processing Record 31 of Set 3 | tsybuliv
# Processing Record 32 of Set 3 | honiara
# Processing Record 33 of Set 3 | sakete
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 3 | west bay
# Processing Record 37 of Set 3 | saint anthony
# Processing Record 38 of Set 3 | puerto narino
# Processing Record 39 of Set 3 | hima
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | kutum
# Processing Record 42 of Set 3 | esperance
# Processing Record 43 of Set 3 | nabire
# Processing Record 44 of Set 3 | pacific grove
# Processing Record 45 of Set 3 | yerbogachen
# Processing Record 46 of Set 3 | anadyr
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | zhifang
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | mezen
# Processing Record 1 of Set 4 | bengkulu
# Processing Record 2 of Set 4 | lasa
# Processing Record 3 of Set 4 | benghazi
# Processing Record 4 of Set 4 | zhanaozen
# Processing Record 5 of Set 4 | meulaboh
# Processing Record 6 of Set 4 | ust-kan
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | nyurba
# Processing Record 9 of Set 4 | narsaq
# Processing Record 10 of Set 4 | marawi
# Processing Record 11 of Set 4 | meybod
# Processing Record 12 of Set 4 | kapit
# Processing Record 13 of Set 4 | arlit
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | pangoa
# Processing Record 16 of Set 4 | claresholm
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | paragominas
# Processing Record 19 of Set 4 | brae
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | craigieburn
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | poum
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 4 | ketchikan
# Processing Record 27 of Set 4 | massakory
# Processing Record 28 of Set 4 | smyrna
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | nhulunbuy
# Processing Record 31 of Set 4 | lavrentiya
# Processing Record 32 of Set 4 | xichang
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | miedzychod
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | talnakh
# Processing Record 38 of Set 4 | indramayu
# Processing Record 39 of Set 4 | caluquembe
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | kidal
# Processing Record 42 of Set 4 | grand gaube
# Processing Record 43 of Set 4 | penjamo
# Processing Record 44 of Set 4 | motygino
# Processing Record 45 of Set 4 | del rio
# Processing Record 46 of Set 4 | lubango
# Processing Record 47 of Set 4 | homer
# Processing Record 48 of Set 4 | north bend
# Processing Record 49 of Set 4 | svetlyy
# Processing Record 50 of Set 4 | tessalit
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | tautira
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | wasilla
# Processing Record 5 of Set 5 | ixtapa
# Processing Record 6 of Set 5 | vizinga
# Processing Record 7 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | bereda
# Processing Record 10 of Set 5 | lakes entrance
# Processing Record 11 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 5 | te anau
# Processing Record 13 of Set 5 | ambanja
# Processing Record 14 of Set 5 | camacha
# Processing Record 15 of Set 5 | llangefni
# Processing Record 16 of Set 5 | fairbanks
# Processing Record 17 of Set 5 | guerrero negro
# Processing Record 18 of Set 5 | zabol
# Processing Record 19 of Set 5 | mountain home
# Processing Record 20 of Set 5 | nong kung si
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | boca do acre
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | lazarev
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | cayenne
# Processing Record 30 of Set 5 | padang
# Processing Record 31 of Set 5 | druzhba
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | qandala
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | tevaitoa
# Processing Record 39 of Set 5 | nuuk
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | manati
# Processing Record 42 of Set 5 | kapra
# Processing Record 43 of Set 5 | egvekinot
# Processing Record 44 of Set 5 | rundu
# Processing Record 45 of Set 5 | san policarpo
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | badalona
# Processing Record 48 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 5 | victoria
# Processing Record 50 of Set 5 | vitim
# Processing Record 1 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 2 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 6 | shimanovsk
# Processing Record 4 of Set 6 | faya
# Processing Record 5 of Set 6 | baghdad
# Processing Record 6 of Set 6 | jaisalmer
# Processing Record 7 of Set 6 | arman
# Processing Record 8 of Set 6 | lander
# Processing Record 9 of Set 6 | bonavista
# Processing Record 10 of Set 6 | huangchuan
# Processing Record 11 of Set 6 | lima
# Processing Record 12 of Set 6 | conde
# Processing Record 13 of Set 6 | pierre
# Processing Record 14 of Set 6 | ambilobe
# Processing Record 15 of Set 6 | mar del plata
# Processing Record 16 of Set 6 | mahibadhoo
# Processing Record 17 of Set 6 | ustye
# Processing Record 18 of Set 6 | jiazi
# Processing Record 19 of Set 6 | pontes e lacerda
# Processing Record 20 of Set 6 | yarada
# Processing Record 21 of Set 6 | yumen
# Processing Record 22 of Set 6 | zhigansk
# Processing Record 23 of Set 6 | ancud
# Processing Record 24 of Set 6 | zheleznodorozhnyy
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | kysyl-syr
# Processing Record 27 of Set 6 | novoaleksandrovsk
# Processing Record 28 of Set 6 | palana
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | makat
# Processing Record 32 of Set 6 | christchurch
# Processing Record 33 of Set 6 | asau
# Processing Record 34 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 6 | dori
# Processing Record 36 of Set 6 | xining
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | dalbandin
# Processing Record 39 of Set 6 | dossor
# Processing Record 40 of Set 6 | kandrian
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | piacabucu
# Processing Record 43 of Set 6 | sao felix do xingu
# Processing Record 44 of Set 6 | guadalupe y calvo
# Processing Record 45 of Set 6 | penzance
# Processing Record 46 of Set 6 | beringovskiy
# Processing Record 47 of Set 6 | ozernovskiy
# Processing Record 48 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 6 | mnogovershinnyy
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | comodoro rivadavia
# Processing Record 2 of Set 7 | fukue
# Processing Record 3 of Set 7 | henties bay
# Processing Record 4 of Set 7 | san patricio
# Processing Record 5 of Set 7 | chake chake
# Processing Record 6 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 7 | tanah merah
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | arraial do cabo
# Processing Record 10 of Set 7 | santana do livramento
# Processing Record 11 of Set 7 | gaya
# Processing Record 12 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 7 | pampa
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | walvis bay
# Processing Record 16 of Set 7 | huinan
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | flinders
# Processing Record 19 of Set 7 | florence
# Processing Record 20 of Set 7 | baltiysk
# Processing Record 21 of Set 7 | toora-khem
# Processing Record 22 of Set 7 | labuhan
# Processing Record 23 of Set 7 | puerto colombia
# Processing Record 24 of Set 7 | andrews
# Processing Record 25 of Set 7 | aktau
# Processing Record 26 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | kaeo
# Processing Record 28 of Set 7 | byron bay
# Processing Record 29 of Set 7 | sapa
# Processing Record 30 of Set 7 | mariental
# Processing Record 31 of Set 7 | rawson
# Processing Record 32 of Set 7 | dongsheng
# Processing Record 33 of Set 7 | teahupoo
# Processing Record 34 of Set 7 | chaman
# Processing Record 35 of Set 7 | husavik
# Processing Record 36 of Set 7 | losevo
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | ludvika
# Processing Record 40 of Set 7 | iralaya
# Processing Record 41 of Set 7 | mangan
# Processing Record 42 of Set 7 | thompson
# Processing Record 43 of Set 7 | ginir
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | lydenburg
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | vichy
# Processing Record 48 of Set 7 | yangliuqing
# Processing Record 49 of Set 7 | aitape
# Processing Record 50 of Set 7 | gornopravdinsk
# Processing Record 1 of Set 8 | sembe
# Processing Record 2 of Set 8 | saint-augustin
# Processing Record 3 of Set 8 | marigot
# Processing Record 4 of Set 8 | umm kaddadah
# Processing Record 5 of Set 8 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 6 of Set 8 | xapuri
# Processing Record 7 of Set 8 | cabanas
# Processing Record 8 of Set 8 | mataram
# Processing Record 9 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 8 | ust-kalmanka
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | muroto
# Processing Record 13 of Set 8 | samana
# Processing Record 14 of Set 8 | viedma
# Processing Record 15 of Set 8 | tera
# Processing Record 16 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 8 | saint-joseph
# Processing Record 18 of Set 8 | black river
# Processing Record 19 of Set 8 | evensk
# Processing Record 20 of Set 8 | mandurah
# Processing Record 21 of Set 8 | nishihara
# Processing Record 22 of Set 8 | vazante
# Processing Record 23 of Set 8 | muzhi
# Processing Record 24 of Set 8 | gazanjyk
# Processing Record 25 of Set 8 | kenora
# Processing Record 26 of Set 8 | fortuna
# Processing Record 27 of Set 8 | burica
# City not found. Skipping...
# Processing Record 28 of Set 8 | boffa
# Processing Record 29 of Set 8 | hope
# Processing Record 30 of Set 8 | ye
# City not found. Skipping...
# Processing Record 31 of Set 8 | ouallam
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | shirokiy
# Processing Record 34 of Set 8 | alice springs
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | mackenzie
# Processing Record 37 of Set 8 | port said
# Processing Record 38 of Set 8 | najran
# Processing Record 39 of Set 8 | svetlaya
# Processing Record 40 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 8 | matara
# Processing Record 42 of Set 8 | longyan
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | magadan
# Processing Record 45 of Set 8 | valparaiso
# Processing Record 46 of Set 8 | matagami
# Processing Record 47 of Set 8 | fandriana
# Processing Record 48 of Set 8 | ulaanbaatar
# Processing Record 49 of Set 8 | dengzhou
# Processing Record 50 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 1 of Set 9 | saryg-sep
# Processing Record 2 of Set 9 | nikolayevka
# Processing Record 3 of Set 9 | aklavik
# Processing Record 4 of Set 9 | port blair
# Processing Record 5 of Set 9 | lisakovsk
# Processing Record 6 of Set 9 | wuwei
# Processing Record 7 of Set 9 | tabou
# Processing Record 8 of Set 9 | tefe
# Processing Record 9 of Set 9 | salekhard
# Processing Record 10 of Set 9 | doka
# Processing Record 11 of Set 9 | luwingu
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 9 | aswan
# Processing Record 15 of Set 9 | abu zabad
# Processing Record 16 of Set 9 | tondano
# Processing Record 17 of Set 9 | trinidad
# Processing Record 18 of Set 9 | pechenga
# Processing Record 19 of Set 9 | shirakawa
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | kashan
# Processing Record 22 of Set 9 | prince rupert
# Processing Record 23 of Set 9 | afgoye
# City not found. Skipping...
# Processing Record 24 of Set 9 | saldanha
# Processing Record 25 of Set 9 | springbok
# Processing Record 26 of Set 9 | lodja
# Processing Record 27 of Set 9 | aksarka
# Processing Record 28 of Set 9 | huarmey
# Processing Record 29 of Set 9 | giyon
# Processing Record 30 of Set 9 | umm lajj
# Processing Record 31 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | otjimbingwe
# Processing Record 33 of Set 9 | high level
# Processing Record 34 of Set 9 | port shepstone
# Processing Record 35 of Set 9 | hendaye
# Processing Record 36 of Set 9 | wahiawa
# Processing Record 37 of Set 9 | scarborough
# Processing Record 38 of Set 9 | baruun-urt
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | griffith
# Processing Record 41 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | la rioja
# Processing Record 45 of Set 9 | eyl
# Processing Record 46 of Set 9 | amapa
# Processing Record 47 of Set 9 | korsakov
# Processing Record 48 of Set 9 | fougamou
# Processing Record 49 of Set 9 | el alto
# Processing Record 50 of Set 9 | yokadouma
# Processing Record 1 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 10 | crewe
# Processing Record 3 of Set 10 | atar
# Processing Record 4 of Set 10 | takob
# City not found. Skipping...
# Processing Record 5 of Set 10 | sibolga
# Processing Record 6 of Set 10 | oparino
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | san jose
# Processing Record 9 of Set 10 | olot
# Processing Record 10 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 10 | shelburne
# Processing Record 12 of Set 10 | vavuniya
# Processing Record 13 of Set 10 | abaete
# Processing Record 14 of Set 10 | coihaique
# Processing Record 15 of Set 10 | waw
# Processing Record 16 of Set 10 | bishopton
# Processing Record 17 of Set 10 | leh
# Processing Record 18 of Set 10 | burnie
# Processing Record 19 of Set 10 | clarence town
# Processing Record 20 of Set 10 | port pirie
# Processing Record 21 of Set 10 | bassano
# Processing Record 22 of Set 10 | calamar
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | tyup
# Processing Record 25 of Set 10 | blankenberge
# Processing Record 26 of Set 10 | goderich
# Processing Record 27 of Set 10 | yatou
# Processing Record 28 of Set 10 | kushmurun
# Processing Record 29 of Set 10 | tyler
# Processing Record 30 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 10 | mayumba
# Processing Record 32 of Set 10 | severodvinsk
# Processing Record 33 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 10 | hanyang
# Processing Record 35 of Set 10 | santa cruz
# Processing Record 36 of Set 10 | vila franca do campo
# Processing Record 37 of Set 10 | bay roberts
# Processing Record 38 of Set 10 | oktyabrskiy
# Processing Record 39 of Set 10 | olinda
# Processing Record 40 of Set 10 | hibbing
# Processing Record 41 of Set 10 | longjiang
# Processing Record 42 of Set 10 | casablanca
# Processing Record 43 of Set 10 | viransehir
# Processing Record 44 of Set 10 | kaitangata
# Processing Record 45 of Set 10 | tuatapere
# Processing Record 46 of Set 10 | mount gambier
# Processing Record 47 of Set 10 | port-gentil
# Processing Record 48 of Set 10 | pingliang
# Processing Record 49 of Set 10 | keflavik
# Processing Record 50 of Set 10 | lagos de moreno
# Processing Record 1 of Set 11 | verkhnevilyuysk
# Processing Record 2 of Set 11 | ovalle
# Processing Record 3 of Set 11 | salalah
# Processing Record 4 of Set 11 | culebra
# Processing Record 5 of Set 11 | dunedin
# Processing Record 6 of Set 11 | chapais
# Processing Record 7 of Set 11 | suez
# Processing Record 8 of Set 11 | kirakira
# Processing Record 9 of Set 11 | khani
# Processing Record 10 of Set 11 | varca
# Processing Record 11 of Set 11 | lashio
# Processing Record 12 of Set 11 | pringsewu
# Processing Record 13 of Set 11 | lebedinyy
# Processing Record 14 of Set 11 | ouro branco
# Processing Record 15 of Set 11 | havre-saint-pierre
# Processing Record 16 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 11 | samarai
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | atbasar
# Processing Record 20 of Set 11 | omboue
# Processing Record 21 of Set 11 | toro
# Processing Record 22 of Set 11 | pemba
# Processing Record 23 of Set 11 | kollam
# Processing Record 24 of Set 11 | inta
# Processing Record 25 of Set 11 | ust-nera
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | muyezerskiy
# Processing Record 30 of Set 11 | malmesbury
# Processing Record 31 of Set 11 | vorotynets
# Processing Record 32 of Set 11 | hamburg
# Processing Record 33 of Set 11 | hailey
# Processing Record 34 of Set 11 | batagay-alyta
# Processing Record 35 of Set 11 | geraldton
# Processing Record 36 of Set 11 | mapiripan
# Processing Record 37 of Set 11 | sobolevo
# Processing Record 38 of Set 11 | belmonte
# Processing Record 39 of Set 11 | pokosnoye
# Processing Record 40 of Set 11 | leshukonskoye
# Processing Record 41 of Set 11 | chara
# Processing Record 42 of Set 11 | hobyo
# Processing Record 43 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 11 | jidong
# Processing Record 45 of Set 11 | suba
# Processing Record 46 of Set 11 | sabang
# Processing Record 47 of Set 11 | almaznyy
# Processing Record 48 of Set 11 | tchibanga
# Processing Record 49 of Set 11 | tura
# Processing Record 50 of Set 11 | banda aceh
# Processing Record 1 of Set 12 | kirando
# Processing Record 2 of Set 12 | laja
# Processing Record 3 of Set 12 | bage
# Processing Record 4 of Set 12 | shiraz
# Processing Record 5 of Set 12 | abapo
# Processing Record 6 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 12 | cap malheureux
# Processing Record 9 of Set 12 | shache
# Processing Record 10 of Set 12 | karratha
# Processing Record 11 of Set 12 | yantal
# Processing Record 12 of Set 12 | constitucion
# Processing Record 13 of Set 12 | matveyevka
# Processing Record 14 of Set 12 | beyneu
# Processing Record 15 of Set 12 | oktyabrskoye
# Processing Record 16 of Set 12 | hirara
# Processing Record 17 of Set 12 | chengmai
# City not found. Skipping...
# Processing Record 18 of Set 12 | goure
# Processing Record 19 of Set 12 | singaraja
# Processing Record 20 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 22 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 23 of Set 12 | kichera
# Processing Record 24 of Set 12 | weyburn
# Processing Record 25 of Set 12 | champerico
# Processing Record 26 of Set 12 | san vicente
# Processing Record 27 of Set 12 | isangel
# Processing Record 28 of Set 12 | dolores
# Processing Record 29 of Set 12 | presidente dutra
# Processing Record 30 of Set 12 | zhezkazgan
# Processing Record 31 of Set 12 | gibara
# Processing Record 32 of Set 12 | navrongo
# Processing Record 33 of Set 12 | porto novo
# Processing Record 34 of Set 12 | katherine
# Processing Record 35 of Set 12 | torrijos
# Processing Record 36 of Set 12 | eden
# Processing Record 37 of Set 12 | ust-ilimsk
# Processing Record 38 of Set 12 | elizabeth city
# Processing Record 39 of Set 12 | parati
# Processing Record 40 of Set 12 | kisangani
# Processing Record 41 of Set 12 | lagoa formosa
# Processing Record 42 of Set 12 | nantucket
# Processing Record 43 of Set 12 | katangli
# Processing Record 44 of Set 12 | west wendover
# Processing Record 45 of Set 12 | jacareacanga
# Processing Record 46 of Set 12 | kaniama
# Processing Record 47 of Set 12 | juneau
# Processing Record 48 of Set 12 | vestmannaeyjar
# Processing Record 49 of Set 12 | makakilo city
# Processing Record 50 of Set 12 | rio gallegos
# Processing Record 1 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 13 | termiz
# Processing Record 3 of Set 13 | sioux lookout
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | flin flon
# Processing Record 6 of Set 13 | mumford
# Processing Record 7 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 13 | yar-sale
# Processing Record 9 of Set 13 | tomatlan
# Processing Record 10 of Set 13 | galway
# Processing Record 11 of Set 13 | berlevag
# Processing Record 12 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | cravo norte
# Processing Record 14 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 13 | shanting
# Processing Record 16 of Set 13 | along
# Processing Record 17 of Set 13 | cap-aux-meules
# Processing Record 18 of Set 13 | amberley
# Processing Record 19 of Set 13 | altay
# Processing Record 20 of Set 13 | fomboni
# Processing Record 21 of Set 13 | ouesso
# Processing Record 22 of Set 13 | jimo
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | qiongshan
# Processing Record 25 of Set 13 | pangkalanbuun
# Processing Record 26 of Set 13 | madang
# Processing Record 27 of Set 13 | biak
# Processing Record 28 of Set 13 | port lincoln
# Processing Record 29 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 13 | balkhash
# Processing Record 31 of Set 13 | namibe
# Processing Record 32 of Set 13 | kiama
# Processing Record 33 of Set 13 | moose factory
# Processing Record 34 of Set 13 | kesova gora
# Processing Record 35 of Set 13 | sabha
# Processing Record 36 of Set 13 | naukot
# Processing Record 37 of Set 13 | inhambane
# Processing Record 38 of Set 13 | abong mbang
# Processing Record 39 of Set 13 | pekalongan
# Processing Record 40 of Set 13 | ponta delgada
# Processing Record 41 of Set 13 | antigonish
# Processing Record 42 of Set 13 | oum hadjer
# Processing Record 43 of Set 13 | puertollano
# Processing Record 44 of Set 13 | kampot
# Processing Record 45 of Set 13 | port moresby
# Processing Record 46 of Set 13 | hay river
# Processing Record 47 of Set 13 | nanakuli
# Processing Record 48 of Set 13 | san lorenzo
# Processing Record 49 of Set 13 | peniche
# Processing Record 50 of Set 13 | namie
# Processing Record 1 of Set 14 | kissing
# Processing Record 2 of Set 14 | kavaratti
# Processing Record 3 of Set 14 | bubaque
# Processing Record 4 of Set 14 | shar
# Processing Record 5 of Set 14 | bunia
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | qasigiannguit
# Processing Record 8 of Set 14 | mpanda
# Processing Record 9 of Set 14 | hami
# Processing Record 10 of Set 14 | havoysund
# Processing Record 11 of Set 14 | novopokrovka
# Processing Record 12 of Set 14 | heihe
# Processing Record 13 of Set 14 | camabatela
# Processing Record 14 of Set 14 | bendigo
# Processing Record 15 of Set 14 | astoria
# Processing Record 16 of Set 14 | saint-jean-port-joli
# Processing Record 17 of Set 14 | codrington
# Processing Record 18 of Set 14 | half moon bay
# Processing Record 19 of Set 14 | gamba
# Processing Record 20 of Set 14 | kovernino
# Processing Record 21 of Set 14 | arona
# Processing Record 22 of Set 14 | dauriya
# Processing Record 23 of Set 14 | manamadurai
# Processing Record 24 of Set 14 | rabaul
# Processing Record 25 of Set 14 | riyadh
# Processing Record 26 of Set 14 | bemidji
# Processing Record 27 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 14 | okoneshnikovo
# Processing Record 29 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | pochutla
# Processing Record 31 of Set 14 | rosetta
# Processing Record 32 of Set 14 | novi bilokorovychi
# Processing Record 33 of Set 14 | meghri
# Processing Record 34 of Set 14 | pitea
# Processing Record 35 of Set 14 | telde
# Processing Record 36 of Set 14 | antri
# Processing Record 37 of Set 14 | iisalmi
# Processing Record 38 of Set 14 | atherton
# Processing Record 39 of Set 14 | miesbach
# Processing Record 40 of Set 14 | oussouye
# Processing Record 41 of Set 14 | bar-le-duc
# Processing Record 42 of Set 14 | sorland
# Processing Record 43 of Set 14 | solnechnyy
# Processing Record 44 of Set 14 | santa maria
# Processing Record 45 of Set 14 | port hardy
# Processing Record 46 of Set 14 | the valley
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | monterey
# Processing Record 49 of Set 14 | birao
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | roma
# Processing Record 2 of Set 15 | bourges
# Processing Record 3 of Set 15 | los llanos de aridane
# Processing Record 4 of Set 15 | sibu
# Processing Record 5 of Set 15 | margate
# Processing Record 6 of Set 15 | uglovka
# Processing Record 7 of Set 15 | fort nelson
# Processing Record 8 of Set 15 | thunder bay
# Processing Record 9 of Set 15 | turek
# Processing Record 10 of Set 15 | bagotville
# Processing Record 11 of Set 15 | koslan
# Processing Record 12 of Set 15 | copiapo
# Processing Record 13 of Set 15 | korhogo
# Processing Record 14 of Set 15 | jalu
# Processing Record 15 of Set 15 | shimoda
# Processing Record 16 of Set 15 | boddam
# Processing Record 17 of Set 15 | mto wa mbu
# Processing Record 18 of Set 15 | grand-santi
# Processing Record 19 of Set 15 | gull lake
# Processing Record 20 of Set 15 | mindelo
# Processing Record 21 of Set 15 | tashtagol
# Processing Record 22 of Set 15 | sao domingos
# Processing Record 23 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 24 of Set 15 | nizhniy tsasuchey
# Processing Record 25 of Set 15 | helena
# Processing Record 26 of Set 15 | chernyshevskiy
# Processing Record 27 of Set 15 | gorontalo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     60.46        36          20
# 1    Norman Wells      CA  65.2820 -126.8329     23.04        86          90
# 2           Locri      IT  38.2414   16.2623     66.16        70         100
# 3          Yulara      AU -25.2406  130.9889     59.67        30          61
# 4         Bohicon      BJ   7.1783    2.0667     75.49        92         100
# 5         Baculin      PH   7.4525  126.5842     78.13        86          59
# 6          Atuona      PF  -9.8000 -139.0333     78.28        71           1
# 7          Miyako      JP  39.6367  141.9525     47.05        75           2
# 8   Cockburn Town      TC  21.4612  -71.1419     82.69        67           3
# 9  Porto Nacional      BR -10.7081  -48.4172     89.60        27          16
#
#    Wind Speed Current Description
# 0       13.80          few clouds
# 1        6.91          light snow
# 2       13.69     overcast clouds
# 3        9.55       broken clouds
# 4        3.80     overcast clouds
# 5        4.90       broken clouds
# 6       17.29           clear sky
# 7        6.44           clear sky
# 8        2.73           clear sky
# 9        0.69          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
